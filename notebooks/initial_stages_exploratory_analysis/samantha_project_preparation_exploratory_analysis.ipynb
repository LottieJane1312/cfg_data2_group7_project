# %% [markdown]
# ## NEW QUESTION: what is the social impact of the prevalence of airbnbs

# %% [markdown]
# # Question idea: Does the prevalence of airbnbs increase or decrease house prices in London?
#
# This would be interesting for people wanting to buy houses in certain areas of London

# %% [markdown]
# Could link to: is there higher crime rates where there are more airbnbs?
# or: Is this correlation with house prices linked to crime rates?

# %%
import pandas as pd
airbnb_data = pd.read_csv('C:/Users/samsh/PycharmProjects/data-2-spring-repo-main/data_notebooks/data/airbnb_listings.csv')
airbnb_data.head()
# Out:
#                    id                                               name
# 0  714569379355913481            Lovely private bedroom in Muswell Hill.  \
# 1  822557738577472503   PropertyPlug - 2Bed Flat in Edgware SmartTV WiFi
# 2             4876550  Stunning Apartment 2 minutes walk to Tube Station
# 3  786791705194673775                               Waddon Coach House 2
# 4  808038970516277767                       Studio Flat  Franklin London
#
#      host_id host_name  neighbourhood_group neighbourhood   latitude
# 0   39009854   Forough                  NaN      Haringey  51.597280  \
# 1  325629338      Paul                  NaN        Harrow  51.608180
# 2   25087384    Joseph                  NaN        Barnet  51.602282
# 3  490795350    Jahmal                  NaN       Croydon  51.370691
# 4  495977998   Hussein                  NaN        Barnet  51.636518
#
#    longitude        room_type  price  minimum_nights  number_of_reviews
# ...

# %%
import pandas as pd
house_price_data = pd.read_csv('C:/Users/samsh/PycharmProjects/data-2-spring-repo-main/data_notebooks/data/UK_House_price_index.csv')
house_price_data.head()
house_price_data.tail()
# Out:
#       Month City of London Barking & Dagenham   Barnet   Bexley    Brent
# 334  Oct-22        902,309            353,521  605,114  406,869  577,223  \
# 335  Nov-22        958,870            356,903  596,539  405,329  572,467
# 336  Dec-22        929,060            356,645  596,638  406,859  564,118
# 337  Jan-23        978,121            352,043  598,835  399,887  560,638
# 338  Feb-23        960,868            344,518  602,510  399,578  548,075
#
#      Bromley   Camden  Croydon   Ealing  ... NORTH WEST YORKS & THE HUMBER
# 334  515,518  845,840  433,202  538,848  ...    218,171            211,638  \
# 335  515,314  834,225  431,935  537,450  ...    219,768            212,549
# 336  515,510  837,359  431,143  540,902  ...    218,317            212,197
# 337  514,159  828,320  430,577  539,560  ...    215,343            207,306
# 338  508,088  848,187  425,364  546,214  ...    214,146            207,220
#
#     EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND   LONDON SOUTH EAST
# ...

# %%
location_of_airbnbs = airbnb_data['neighbourhood']
location_of_airbnbs

airbnb_barnet = airbnb_data['neighbourhood'].nunique()
airbnb_barnet
# Out:
# 33

# %%
import matplotlib.pyplot as plt

x = months = airbnb_data['id'].count()

y =

# %% [markdown]
# # Question idea 2: Is there a correlation between monthly house prices and monthly crime levels (in London)?
#
# This would be interesting for people looking to buy houses and deciding on which area to live in - they might think a cheaper house is more value for money, but might mean the area is not as safe.
#
# This could be linked to levels of happiness - more factors contributing to someone wanting to buy a house.

# %%
import pandas as pd
house_price_data = pd.read_csv('C:/Users/samsh/PycharmProjects/data-2-spring-repo-main/data_notebooks/data/UK_House_price_index.csv')
house_price_data.head()
house_price_data.tail()
# Out:
#       Month City of London Barking & Dagenham   Barnet   Bexley    Brent
# 334  Oct-22        902,309            353,521  605,114  406,869  577,223  \
# 335  Nov-22        958,870            356,903  596,539  405,329  572,467
# 336  Dec-22        929,060            356,645  596,638  406,859  564,118
# 337  Jan-23        978,121            352,043  598,835  399,887  560,638
# 338  Feb-23        960,868            344,518  602,510  399,578  548,075
#
#      Bromley   Camden  Croydon   Ealing  ... NORTH WEST YORKS & THE HUMBER
# 334  515,518  845,840  433,202  538,848  ...    218,171            211,638  \
# 335  515,314  834,225  431,935  537,450  ...    219,768            212,549
# 336  515,510  837,359  431,143  540,902  ...    218,317            212,197
# 337  514,159  828,320  430,577  539,560  ...    215,343            207,306
# 338  508,088  848,187  425,364  546,214  ...    214,146            207,220
#
#     EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND   LONDON SOUTH EAST
# ...

# %% [markdown]
# This shows the the monthly average house prices per borough in London from Jan 95 to Feb 23.Taken from the Land Registry.
# Also has averages in other locations of the country.

# %%
import pandas as pd
police_data = pd.read_csv('C:/Users/samsh/PycharmProjects/data-2-spring-repo-main/data_notebooks/data/MPS_Borough_Level_Crime.csv')
police_data.head()
# Out:
#                    MajorText                        MinorText
# 0  Arson and Criminal Damage                            Arson  \
# 1  Arson and Criminal Damage                  Criminal Damage
# 2                   Burglary  Burglary Business and Community
# 3                   Burglary                Domestic Burglary
# 4              Drug Offences                 Drug Trafficking
#
#      LookUp_BoroughName  202104  202105  202106  202107  202108  202109
# 0  Barking and Dagenham       6       6       5       4      12       5  \
# 1  Barking and Dagenham      99     128     142     130     144     111
# 2  Barking and Dagenham      12      30      24      21      29      27
# 3  Barking and Dagenham      75      81      66      61      87      62
# 4  Barking and Dagenham       9       9       7       6      11      17
#
#    202110  ...  202206  202207  202208  202209  202210  202211  202212
# 0       7  ...       5       9       5       4       4       3       1  \
# ...

# %% [markdown]
# This data from the Met police shows the number of crimes by category in each borough from 04/21 to 03/23.

# %%
import matplotlib.pyplot as plt
import numpy as np

Month = police_data['202104'].tolist()
Crime = police_data['MajorText'].tolist()

plt.scatter(Month, Crime)
plt.title('Crimes per month')
plt.ylabel('Crime')
plt.xlabel('Month')

plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# fig = plt.figure()
# fig.add_subplot(111, projection='3d') 
# x = crime = police_data['MajorText'].tolist()


# y1 = police_data['202104'].tolist()
# y2 = police_data['202105'].tolist()
# y3 = police_data['202106'].tolist()
# y4 = police_data['202106'].tolist()
# y5 = police_data['202107'].tolist()
# y6 = police_data['202108'].tolist()

# z = police_data['Barking and Dagenham']

# plt.plot(x,y1, 'blue', label='202104',linewidth=5, marker = 'o')
# plt.plot(x,y2, 'orange', label='202105',linewidth=5, marker = 'o')
# plt.plot(x,y3,'green', label='202106',linewidth=5, marker = 'o')
# plt.plot(x,y4,'red', label='202107',linewidth=5, marker = 'o')
# plt.plot(x,y5,'purple', label='202108',linewidth=5, marker = 'o')
# plt.plot(x,y6,'brown', label='202109',linewidth=5, marker = 'o')

# plt.title('Barking and Dagenham crimes')
# plt.ylabel('Month')
# plt.xlabel('Crime')

# plt.legend()

# %%
import pandas as pd
london_price_data = pd.read_csv('C:/Users/samsh/PycharmProjects/data-2-spring-repo-main/data_notebooks/data/London_average_prices.csv')
london_price_data.head()
# Out:
#     Month City of London Barking & Dagenham   Barnet   Bexley    Brent
# 0  Apr-21        748,815            310,454  534,687  358,992  493,682  \
# 1  May-21        756,082            309,571  538,012  359,007  507,153
# 2  Jun-21        773,492            314,031  546,801  362,288  514,005
# 3  Jul-21        948,729            309,541  541,711  365,740  525,506
# 4  Aug-21        953,551            313,791  555,311  370,500  519,287
#
#    Bromley   Camden  Croydon   Ealing  ...   Merton   Newham Redbridge
# 0  455,807  810,042  393,783  498,632  ...  536,378  390,513   446,034  \
# 1  460,556  821,255  393,858  496,876  ...  535,372  382,881   444,311
# 2  467,240  812,856  394,957  499,212  ...  538,421  387,205   452,279
# 3  469,521  872,821  393,696  507,125  ...  534,041  384,340   449,437
# 4  471,441  872,473  396,512  514,378  ...  541,204  389,475   454,010
#
#   Richmond upon Thames Southwark   Sutton Tower Hamlets Waltham Forest
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

month = london_price_data['Month'].tolist()
average_prices = london_price_data['Barking & Dagenham'].tolist()

month
average_prices

plt.plot(month, average_prices)
plt.title('Average prices per month for Barking and Dagenham')
plt.ylabel('average_prices')
plt.xlabel('Month')

plt.show()

# %%
import pandas as pd
barking_data = pd.read_csv('C:/Users/samsh/PycharmProjects/data-2-spring-repo-main/data_notebooks/data/Barking_data.csv')
barking_data.head()
# Out:
#     Month Arson and Criminal Damage Arson and Criminal Damage.1
# 0   Month                     Arson             Criminal Damage  \
# 1  202104                         6                          99
# 2  202105                         6                         128
# 3  202106                         5                         142
# 4  202107                         4                         130
#
#                           Burglary         Burglary.1     Drug Offences
# 0  Burglary Business and Community  Domestic Burglary  Drug Trafficking  \
# 1                               12                 75                 9
# 2                               30                 81                 9
# 3                               24                 66                 7
# 4                               21                 61                 6
#
#        Drug Offences.1 Miscellaneous Crimes Against Society
# 0  Possession of Drugs                        Bail Offences  \
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

month = barking_data['Month'].tolist()
crime = barking_data['Burglary'].tolist()

month
average_prices

plt.plot(month, crime)
plt.title('Crimes per month for Barking and Dagenham')
plt.ylabel('Burglary')
plt.xlabel('Month')

plt.show()
